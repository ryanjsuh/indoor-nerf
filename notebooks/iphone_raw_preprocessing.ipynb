# %%
from google.colab import drive, auth
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !apt-get -y update && apt-get -y install colmap
# !pip install --quiet pillow piexif pillow-heif
# !git clone --quiet https://github.com/NVlabs/instant-ngp
# %cd instant-ngp/scripts
# !curl -s https://raw.githubusercontent.com/NVlabs/instant-ngp/master/scripts/colmap2nerf.py -o colmap2nerf.py
# %cd /content
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,726 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,245 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,517 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,946 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,546 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,363 kB]
# Get:20 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [77.3 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,934 kB]
# Fetched 30.6 MB in 3s (9,149 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libamd2 libcamd2 libccolamd2 libceres2 libcholmod3 libcolamd2 libcxsparse3
#   libevdev2 libfreeimage3 libgflags2.2 libgoogle-glog0v5 libgudev-1.0-0
#   libinput-bin libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common libwacom9
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0
#   qt5-gtk-platformtheme qttranslations5-l10n
# Suggested packages:
#   qt5-image-formats-plugins qtwayland5
# The following NEW packages will be installed:
#   colmap libamd2 libcamd2 libccolamd2 libceres2 libcholmod3 libcolamd2
#   libcxsparse3 libevdev2 libfreeimage3 libgflags2.2 libgoogle-glog0v5
#   libgudev-1.0-0 libinput-bin libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1
#   libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5
#   libraw20 libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0
#   qt5-gtk-platformtheme qttranslations5-l10n
# 0 upgraded, 42 newly installed, 0 to remove and 89 not upgraded.
# Need to get 17.5 MB of archives.
# After this operation, 68.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsuitesparseconfig5 amd64 1:5.10.1+dfsg-4build1 [10.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libamd2 amd64 1:5.10.1+dfsg-4build1 [21.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcamd2 amd64 1:5.10.1+dfsg-4build1 [23.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libccolamd2 amd64 1:5.10.1+dfsg-4build1 [25.2 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolamd2 amd64 1:5.10.1+dfsg-4build1 [18.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmetis5 amd64 5.1.0.dfsg-7build2 [181 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcholmod3 amd64 1:5.10.1+dfsg-4build1 [346 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcxsparse3 amd64 1:5.10.1+dfsg-4build1 [70.8 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgflags2.2 amd64 2.2.2-2 [78.1 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgoogle-glog0v5 amd64 0.5.0+really0.4.0-2 [60.3 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspqr2 amd64 1:5.10.1+dfsg-4build1 [71.6 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libceres2 amd64 2.0.0+dfsg1-5 [834 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libraw20 amd64 0.20.2-2ubuntu2.22.04.2 [342 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libfreeimage3 amd64 3.18.0+ds2-6ubuntu5.1 [294 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 colmap amd64 3.7-2 [2,998 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 17.5 MB in 1s (14.7 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libqt5core5a:amd64.
# (Reading database ... 126102 files and directories currently installed.)
# Preparing to unpack .../00-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../01-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../02-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../03-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../04-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../05-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../06-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../07-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../08-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../09-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../10-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../11-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../12-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../13-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../14-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../15-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../16-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../17-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../18-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../19-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../20-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../21-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../22-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# Preparing to unpack .../23-libsuitesparseconfig5_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../24-libamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcamd2:amd64.
# Preparing to unpack .../25-libcamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libccolamd2:amd64.
# Preparing to unpack .../26-libccolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../27-libcolamd2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libmetis5:amd64.
# Preparing to unpack .../28-libmetis5_5.1.0.dfsg-7build2_amd64.deb ...
# Unpacking libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Selecting previously unselected package libcholmod3:amd64.
# Preparing to unpack .../29-libcholmod3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libcxsparse3:amd64.
# Preparing to unpack .../30-libcxsparse3_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../31-libgflags2.2_2.2.2-2_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-2) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../32-libgoogle-glog0v5_0.5.0+really0.4.0-2_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Selecting previously unselected package libspqr2:amd64.
# Preparing to unpack .../33-libspqr2_1%3a5.10.1+dfsg-4build1_amd64.deb ...
# Unpacking libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Selecting previously unselected package libceres2.
# Preparing to unpack .../34-libceres2_2.0.0+dfsg1-5_amd64.deb ...
# Unpacking libceres2 (2.0.0+dfsg1-5) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../35-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libraw20:amd64.
# Preparing to unpack .../36-libraw20_0.20.2-2ubuntu2.22.04.2_amd64.deb ...
# Unpacking libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Selecting previously unselected package libfreeimage3:amd64.
# Preparing to unpack .../37-libfreeimage3_3.18.0+ds2-6ubuntu5.1_amd64.deb ...
# Unpacking libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Selecting previously unselected package colmap.
# Preparing to unpack .../38-colmap_3.7-2_amd64.deb ...
# Unpacking colmap (3.7-2) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../39-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../40-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../41-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libmetis5:amd64 (5.1.0.dfsg-7build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libraw20:amd64 (0.20.2-2ubuntu2.22.04.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libcxsparse3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libgflags2.2 (2.2.2-2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up libamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libfreeimage3:amd64 (3.18.0+ds2-6ubuntu5.1) ...
# Setting up libcolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up libcamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libccolamd2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libgoogle-glog0v5 (0.5.0+really0.4.0-2) ...
# Setting up libcholmod3:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libspqr2:amd64 (1:5.10.1+dfsg-4build1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libceres2 (2.0.0+dfsg1-5) ...
# Setting up colmap (3.7-2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 79.1 MB/s eta 0:00:00
# /content/instant-ngp/scripts
# /content

# %%
# directory setup
from pathlib import Path

DATA_ROOT = Path('/content/drive/My Drive/cs231n_nerf/datasets')
RAW_ROOT = DATA_ROOT / 'iphone_raw'

PROCESSED_ROOT = Path('/content/drive/My Drive/cs231n_nerf/datasets/iphone_processed')

ORIG_ROOT = PROCESSED_ROOT / 'original_processed'
ALLSHOT_ROOT = PROCESSED_ROOT / 'allshot_hashnerf_processed'
FEWSHOT_ROOT = PROCESSED_ROOT / 'fewshot_hashnerf_processed'

for root in (PROCESSED_ROOT, ORIG_ROOT, ALLSHOT_ROOT, FEWSHOT_ROOT):
  root.mkdir(parents=True, exist_ok=True)

# %%
# processing of one specified room folder in iphone_raw/

import numpy as np
import os, subprocess, json, glob, piexif, pillow_heif, math, shutil
from pathlib import Path
from PIL import Image, ImageOps

# CHANGE NAME OF FOLDER FOR YOUR USE
room_name = 'suites_bedroom'
TARGET_SIDE = 1600 # resize long side of image for memory constraints

room_dir = RAW_ROOT / room_name
if not room_dir.is_dir():
  raise FileNotFoundError(f"Room folder {room_dir} could not be found")

# exposure value (EV) calculation for varying iso
def shutter_iso_to_ev(shutter, iso):
  return math.log2((100 * shutter) / iso)

def estimate_ev_linear(img_path, L0=0.18, pct=(5, 95)):
  rgb = np.array(Image.open(img_path), dtype=np.float32) / 255.0
  mask = rgb <= 0.04045
  lin = np.where(mask, rgb/12.92, ((rgb+0.055)/1.055)**2.4)

  Y = 0.2126*lin[...,0] + 0.7152*lin[...,1] + 0.0722*lin[...,2]
  low, high = np.percentile(Y, pct)
  Y_trim = Y[(Y >= low) & (Y <= high)]
  L = float(Y_trim.mean())
  return np.log2(L / L0)

# invoke shell
def run(cmd):
  subprocess.run(cmd, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)

# scratch directories
work_dir = Path(f'/content/tmp_{room_name}')
imgs_out = work_dir / 'images'
sparse = work_dir / 'sparse'
db_path = work_dir / 'colmap.db'

shutil.rmtree(work_dir, ignore_errors=True)
imgs_out.mkdir(parents=True, exist_ok=True)

all_srcs = sorted([p for p in room_dir.iterdir() if p.suffix.lower() in {'.jpg', '.png', '.heic'}])

# precompute EVs in same order
ev_list = []
for src in all_srcs:
  exif_dict = piexif.load(str(src))
  exif_ifd = exif_dict.get('Exif', {})

  # raw_shutter = exif_ifd.get(piexif.ExifIFD.ExposureTime, None)
  # shutter = (raw_shutter[0] / raw_shutter[1]) if isinstance(raw_shutter, tuple) else (1 / 60)
  # raw_iso = exif_ifd.get(piexif.ExifIFD.ISOSpeedRatings, None)
  # iso = raw_iso if isinstance(raw_iso, int) else 100
  # ev_list.append(shutter_iso_to_ev(shutter, iso))

  raw_shutter = exif_ifd.get(piexif.ExifIFD.ExposureTime, None)
  raw_iso = exif_ifd.get(piexif.ExifIFD.ISOSpeedRatings, None)
  if raw_shutter and isinstance(raw_shutter, tuple) and isinstance(raw_iso, int):
    shutter = raw_shutter[0] / raw_shutter[1]
    iso = raw_iso
    ev = shutter_iso_to_ev(shutter, iso)
  else:
    ev = estimate_ev_linear(src)
  ev_list.append(ev)


# copy + rotate + scale down, saving as PNG
for i, src in enumerate(all_srcs):
  img = Image.open(src)
  # ONLY ROTATE FOR THESE TYPE OF IPHONE IMAGES
  img = img.rotate(-90, expand=True)
  img.thumbnail((TARGET_SIDE, TARGET_SIDE), Image.LANCZOS)
  img.save(imgs_out/f'{i:08d}.png', format='PNG', quality=95)

# feature extraction
run(f"colmap feature_extractor "
    f"--database_path {db_path} "
    f"--image_path {imgs_out} "
    f"--ImageReader.single_camera 1 "
    f"--ImageReader.camera_model SIMPLE_PINHOLE "
    f"--ImageReader.default_focal_length_factor 1 "
    f"--SiftExtraction.use_gpu 0 "
    f"--SiftExtraction.max_image_size {TARGET_SIDE}")

# sequential (OR can choose exhaustive) matching
run(f"colmap sequential_matcher "
    f"--database_path {db_path} "
    f"--SiftMatching.use_gpu 0 "
    f"--SiftMatching.guided_matching 1")

# mapping (structure -> motion)
shutil.rmtree(sparse, ignore_errors=True)
sparse.mkdir(parents=True, exist_ok=True)

run(f"colmap mapper "
    f"--database_path {db_path} "
    f"--image_path {imgs_out} "
    f"--output_path {sparse} "
    f"--Mapper.num_threads 8 "
    f"--Mapper.init_min_tri_angle 4")

# get largest model
model_dir = max(sparse.glob('*'), key=lambda p: (p / 'images.bin').stat().st_size)
sparse_txt = work_dir / 'sparse_text'
sparse_txt.mkdir(parents=True, exist_ok=True)
run(f"colmap model_converter "
    f"--input_path {model_dir} "
    f"--output_path {sparse_txt} "
    f"--output_type TXT")

# COLMAP to transforms.json (Instant-NGP compatible)
# %cd /content/instant-ngp/scripts
transforms = work_dir / 'transforms.json'
run(f"python colmap2nerf.py "
    f"--colmap_matcher sequential "
    f"--images {imgs_out} "
    f"--text {sparse_txt} "
    f"--out {transforms}")
# %cd /content

# attach precomputed EVs
data = json.load(open(transforms))
for frame in data['frames']:
  idx = int(Path(frame['file_path']).stem)
  frame['exposure_val'] = ev_list[idx]
json.dump(data, open(work_dir / 'transforms.json', 'w'), indent=2)

# get this processed work_dir into Drive (permanent)
final_dir = ORIG_ROOT / room_name
shutil.rmtree(final_dir, ignore_errors=True) # OVERWRITE IF RERUN
shutil.move(str(work_dir), final_dir)
print(f'Done with processing {room_name} to {final_dir}')
# Out:
# /content/instant-ngp/scripts
# /content
# Done with processing suites_bedroom to /content/drive/My Drive/cs231n_nerf/datasets/iphone_processed/original_processed/suites_bedroom

# %% [markdown]
# ## Generating data splits (train, val, test)

# %%
# creating train/val/test split for ALL PHOTOS in HashNeRF-pytorch baseline
import json, random, shutil
from pathlib import Path

# CHANGE NAME OF FOLDER FOR YOUR USE
room_name = 'suites_bedroom'

src = ORIG_ROOT / room_name
dst = ALLSHOT_ROOT / room_name
shutil.copytree(src, dst, dirs_exist_ok=True)

transforms_file = dst / 'transforms.json'

data = json.loads(transforms_file.read_text())
for frame in data['frames']:
  stem = Path(frame['file_path']).stem
  frame['file_path'] = f'images/{stem}'
transforms_file.write_text(json.dumps(data, indent=2))

frames = data['frames']
N = len(frames)
idxs = list(range(N))
random.seed(0)
random.shuffle(idxs)

n_train = int(0.8 * N)
n_val = int(0.1 * N)
train_idxs = idxs[:n_train]
val_idxs = idxs[n_train : n_train + n_val]
test_idxs = idxs[n_train + n_val : ]

for split, sel in [('train', train_idxs), ('val', val_idxs), ('test', test_idxs)]:
  split_data = dict(data)
  split_data['frames'] = [frames[i] for i in sel]
  out_path = dst / f"transforms_{split}.json"
  out_path.write_text(json.dumps(split_data, indent=2))

# %%
# creating train/val/test split for FEW-SHOT approach in HashNeRF-pytorch baseline
import json, random, shutil
from pathlib import Path

# CHANGE NAME OF FOLDER FOR YOUR USE
room_name = 'suites_bedroom'

src = ORIG_ROOT / room_name
dst = FEWSHOT_ROOT / room_name
shutil.copytree(src, dst, dirs_exist_ok=True)

transforms_file = dst / 'transforms.json'
data = json.loads(transforms_file.read_text())
for frame in data['frames']:
  stem = Path(frame['file_path']).stem
  frame['file_path'] = f'images/{stem}'
transforms_file.write_text(json.dumps(data, indent=2))

frames = data['frames']
N = len(frames)
idxs = list(range(N))
random.seed(0)
random.shuffle(idxs)

n_train = 8
n_val = 2
n_test = 20

train_idxs = sorted(idxs[:n_train])
val_idxs = sorted(idxs[n_train : n_train + n_val])
test_idxs = sorted(idxs[n_train + n_val : n_train + n_val + n_test])

for split, sel in [('train', train_idxs), ('val', val_idxs), ('test', test_idxs)]:
  split_data = dict(data)
  split_data['frames'] = [frames[i] for i in sel]
  out_path = dst / f"transforms_{split}.json"
  out_path.write_text(json.dumps(split_data, indent=2))

# %% [markdown]
# ## Transferring Data from Google Drive to VM Instance

# %%
# START OF DATA TRANSFER FROM GOOGLE DRIVE TO VM INSTANCE
# !gcloud auth login --no-launch-browser

# %%
# ONLY RUN IF YOU WANT TO REPLACE EVERYTHING IN GCS BUCKET
# !gsutil -m rm -r "gs://cs231n-data-459006/iphone_processed/*"
# Out:
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/colmap.db#1747483525958310...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000000.png#1747483536591898...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000001.png#1747483538245042...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000002.png#1747483529803518...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000004.png#1747483539097462...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000005.png#1747483538502918...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000003.png#1747483534904478...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000006.png#1747483530949668...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000007.png#1747483529705445...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000008.png#1747483533444126...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000009.png#1747483528597140...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000010.png#1747483534471199...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000011.png#1747483530212958...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000012.png#1747483532145323...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000013.png#1747483528559159...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000014.png#1747483538046681...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000015.png#1747483537351879...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000016.png#1747483529650915...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000017.png#1747483530377674...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000018.png#1747483533867552...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000019.png#1747483533182065...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000020.png#1747483531756571...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000021.png#1747483537620101...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000022.png#1747483537809293...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000023.png#1747483538875014...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000024.png#1747483532127870...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000025.png#1747483535387294...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000026.png#1747483531782710...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000027.png#1747483527963913...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000028.png#1747483529840880...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000029.png#1747483535432494...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000030.png#1747483539358345...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000031.png#1747483534287558...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000032.png#1747483531093032...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000033.png#1747483536721312...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000034.png#1747483534824362...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000035.png#1747483528456874...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000036.png#1747483532999426...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000037.png#1747483537105702...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000038.png#1747483531062384...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000039.png#1747483538690860...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000040.png#1747483540141721...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000041.png#1747483529791255...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000042.png#1747483537538232...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000043.png#1747483532827500...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000044.png#1747483527095454...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000045.png#1747483528216182...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000046.png#1747483534337448...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000047.png#1747483526485910...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000048.png#1747483533546725...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000049.png#1747483535219912...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000050.png#1747483527917757...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000051.png#1747483528825033...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000052.png#1747483536425190...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000053.png#1747483536668766...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000054.png#1747483531559718...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000055.png#1747483528679940...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000056.png#1747483536335464...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000057.png#1747483526670795...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000058.png#1747483529916383...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000059.png#1747483527406018...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000060.png#1747483535707510...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000061.png#1747483528048163...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000062.png#1747483531475100...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000063.png#1747483536275836...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000064.png#1747483533328284...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000065.png#1747483538233558...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000066.png#1747483535854033...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000067.png#1747483535334013...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000068.png#1747483539981489...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000069.png#1747483539937324...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000070.png#1747483534622660...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000071.png#1747483532822543...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000072.png#1747483533213441...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000073.png#1747483527381963...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000074.png#1747483532275115...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000076.png#1747483539600475...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000075.png#1747483531366431...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000077.png#1747483538110641...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000078.png#1747483536493921...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000079.png#1747483534523602...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000080.png#1747483534395817...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000081.png#1747483531235725...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000082.png#1747483538409228...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000083.png#1747483529903976...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000084.png#1747483529619207...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000085.png#1747483533134487...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000086.png#1747483536493215...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000087.png#1747483539724014...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000088.png#1747483535588748...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000089.png#1747483533156901...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000090.png#1747483537562612...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000091.png#1747483532443972...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000092.png#1747483539946478...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000093.png#1747483534475556...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/images/00000094.png#1747483538997698...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse/0/cameras.bin#1747483525319736...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse/0/images.bin#1747483525901941...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse/0/points3D.bin#1747483527518052...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse/0/project.ini#1747483525721868...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse_text/cameras.txt#1747483525060756...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse_text/images.txt#1747483525845247...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/sparse_text/points3D.txt#1747483527930938...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/transforms.json#1747483524951493...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/transforms_test.json#1747483524698725...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/transforms_train.json#1747483525165418...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room/transforms_val.json#1747483523787662...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/colmap.db#1747483545946840...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000000.png#1747483557204079...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000001.png#1747483557848311...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000002.png#1747483548314296...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000003.png#1747483555253731...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000004.png#1747483559160679...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000005.png#1747483558751296...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000006.png#1747483550383381...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000007.png#1747483548967514...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000008.png#1747483553871811...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000009.png#1747483548944995...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000010.png#1747483554966901...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000011.png#1747483549366129...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000013.png#1747483548220081...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000012.png#1747483552629509...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000014.png#1747483557516444...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000015.png#1747483557568635...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000016.png#1747483550680958...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000017.png#1747483550810517...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000018.png#1747483554699133...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000019.png#1747483553175651...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000020.png#1747483551396359...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000021.png#1747483558017610...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000022.png#1747483558213685...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000023.png#1747483559805813...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000024.png#1747483552763399...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000025.png#1747483555882625...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000026.png#1747483552406428...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000027.png#1747483547089262...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000028.png#1747483549109128...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000029.png#1747483556541077...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000030.png#1747483558817012...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000031.png#1747483554694799...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000032.png#1747483552279605...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000033.png#1747483557829101...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000034.png#1747483554228273...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000035.png#1747483548321671...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000036.png#1747483553500207...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000037.png#1747483556844328...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000038.png#1747483550739310...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000039.png#1747483559083400...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000040.png#1747483559180264...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000041.png#1747483549134246...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000042.png#1747483557317175...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000043.png#1747483552111864...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000044.png#1747483546916205...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000045.png#1747483547706012...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000046.png#1747483555483988...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000047.png#1747483546037146...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000049.png#1747483554820569...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000048.png#1747483553650332...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000050.png#1747483547050212...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000051.png#1747483548491508...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000052.png#1747483556316859...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000053.png#1747483556954686...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000054.png#1747483551022591...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000055.png#1747483548106523...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000056.png#1747483556468173...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000057.png#1747483547105341...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000058.png#1747483550648008...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000059.png#1747483547073589...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000060.png#1747483555840676...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000061.png#1747483546701027...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000062.png#1747483550671740...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000063.png#1747483556164365...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000064.png#1747483553472053...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000065.png#1747483558010827...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000066.png#1747483556103954...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000067.png#1747483555836772...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000068.png#1747483559177517...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000069.png#1747483558835231...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000070.png#1747483555407952...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000071.png#1747483552862702...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000072.png#1747483553767562...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000073.png#1747483546410260...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000074.png#1747483551907540...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000075.png#1747483550843735...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000076.png#1747483559869984...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000077.png#1747483558133378...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000078.png#1747483556743347...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000079.png#1747483554790202...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000080.png#1747483554478370...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000081.png#1747483551758402...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000082.png#1747483558024826...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000083.png#1747483549231440...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000084.png#1747483549468289...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000085.png#1747483553518209...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000086.png#1747483556941515...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000087.png#1747483559818398...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000088.png#1747483555971051...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000089.png#1747483553791359...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000090.png#1747483558000108...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000091.png#1747483551930102...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000092.png#1747483559276441...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000093.png#1747483554923685...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000094.png#1747483558585672...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000095.png#1747483549269721...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000096.png#1747483559690268...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000097.png#1747483548139229...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000098.png#1747483549277643...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000099.png#1747483548112423...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000100.png#1747483547107113...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000101.png#1747483555688809...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000102.png#1747483556994288...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000103.png#1747483548703040...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000104.png#1747483553125132...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000105.png#1747483550584907...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000106.png#1747483552782319...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000107.png#1747483550331474...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000108.png#1747483552033361...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000109.png#1747483549949159...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000110.png#1747483549375952...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000111.png#1747483558331871...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/images/00000112.png#1747483555543165...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/0/cameras.bin#1747483545989741...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/0/images.bin#1747483547245265...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/0/points3D.bin#1747483546750448...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/0/project.ini#1747483545303615...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/1/cameras.bin#1747483544726559...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/1/images.bin#1747483545997911...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/1/points3D.bin#1747483545296720...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse/1/project.ini#1747483544643627...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse_text/cameras.txt#1747483545067295...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse_text/images.txt#1747483546462271...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/sparse_text/points3D.txt#1747483545903679...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/transforms.json#1747483544466692...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/transforms_test.json#1747483544160867...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/transforms_train.json#1747483544611806...
# Removing gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom/transforms_val.json#1747483544743690...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/colmap.db#1747483567759645...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000000.png#1747483575007526...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000001.png#1747483576125562...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000002.png#1747483569247468...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000003.png#1747483573821997...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000004.png#1747483577307033...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000005.png#1747483577803445...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000006.png#1747483570977068...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000007.png#1747483568375274...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000008.png#1747483573398435...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000009.png#1747483568867174...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000010.png#1747483573216473...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000011.png#1747483569888735...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000012.png#1747483571074700...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000013.png#1747483568223857...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000014.png#1747483575947121...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000015.png#1747483576052426...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000016.png#1747483569345763...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000017.png#1747483569540814...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000018.png#1747483572750524...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000019.png#1747483571679327...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000020.png#1747483570553932...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000021.png#1747483577015107...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000022.png#1747483576892597...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000023.png#1747483577196749...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000024.png#1747483570983013...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000025.png#1747483574789148...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000026.png#1747483570620469...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000027.png#1747483566683725...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000028.png#1747483569486121...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000029.png#1747483574223583...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000030.png#1747483577231632...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000031.png#1747483573114930...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000032.png#1747483570583057...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000033.png#1747483575705403...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000034.png#1747483572817040...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000035.png#1747483567694924...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000036.png#1747483571605379...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000037.png#1747483575127973...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000038.png#1747483570386393...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000039.png#1747483577302272...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000040.png#1747483578776341...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000041.png#1747483568561426...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000042.png#1747483575783423...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000043.png#1747483572102339...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000044.png#1747483567362193...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000045.png#1747483568043788...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000046.png#1747483572967928...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000047.png#1747483566261216...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000048.png#1747483572041628...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000049.png#1747483573959110...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000050.png#1747483567371579...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000051.png#1747483568010308...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000052.png#1747483574874132...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000053.png#1747483576150588...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000054.png#1747483569963325...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000055.png#1747483568383515...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000056.png#1747483574292442...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000057.png#1747483566639541...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000058.png#1747483570405232...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000059.png#1747483566926842...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000060.png#1747483574699769...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000061.png#1747483566892317...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000062.png#1747483569998926...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000063.png#1747483575803015...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000064.png#1747483573252300...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000065.png#1747483576077629...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000066.png#1747483574984874...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000067.png#1747483573964575...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000068.png#1747483578197870...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000069.png#1747483577582695...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000070.png#1747483573800860...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000071.png#1747483571908835...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000072.png#1747483572090066...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000073.png#1747483566518447...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000074.png#1747483571494839...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000075.png#1747483569645085...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000076.png#1747483578732760...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000077.png#1747483576866676...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000078.png#1747483575269191...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000079.png#1747483573673978...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000080.png#1747483573876857...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000081.png#1747483571585102...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000082.png#1747483576310123...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000083.png#1747483568842717...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000084.png#1747483569938175...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000085.png#1747483572098333...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000086.png#1747483575269484...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000087.png#1747483578142835...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000088.png#1747483574374703...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000089.png#1747483571637556...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000090.png#1747483576580113...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000091.png#1747483570873714...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000092.png#1747483577754106...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000093.png#1747483572613017...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/images/00000094.png#1747483576906858...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse/0/cameras.bin#1747483564132321...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse/0/images.bin#1747483565817605...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse/0/points3D.bin#1747483565288387...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse/0/project.ini#1747483563124812...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse_text/cameras.txt#1747483565071315...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse_text/images.txt#1747483565000626...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/sparse_text/points3D.txt#1747483565130226...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/transforms.json#1747483564972199...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/transforms_test.json#1747483566597173...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/transforms_train.json#1747483564894229...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room/transforms_val.json#1747483565320260...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/colmap.db#1747483585725678...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000000.png#1747483594624530...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000001.png#1747483595952924...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000002.png#1747483587583381...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000003.png#1747483593227118...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000004.png#1747483597356740...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000005.png#1747483596736079...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000006.png#1747483590217640...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000007.png#1747483588070859...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000008.png#1747483591863136...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000010.png#1747483593371588...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000009.png#1747483587187075...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000011.png#1747483588216872...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000012.png#1747483590822716...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000013.png#1747483587268297...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000014.png#1747483595694930...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000015.png#1747483595647682...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000016.png#1747483588682829...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000017.png#1747483589041251...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000018.png#1747483592033527...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000019.png#1747483591257942...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000020.png#1747483589727495...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000021.png#1747483596210129...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000022.png#1747483596505794...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000023.png#1747483598000362...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000024.png#1747483590490446...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000025.png#1747483593432582...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000026.png#1747483590061566...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000027.png#1747483586172393...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000028.png#1747483588509888...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000029.png#1747483593604668...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000030.png#1747483596955672...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000031.png#1747483592454818...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000032.png#1747483589928071...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000033.png#1747483595194370...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000034.png#1747483592241082...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000035.png#1747483586695833...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000036.png#1747483590917184...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000037.png#1747483594924685...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000038.png#1747483589467585...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000039.png#1747483596802689...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000040.png#1747483598141644...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000041.png#1747483587633574...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000042.png#1747483596237294...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000043.png#1747483590716905...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000044.png#1747483585750377...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000045.png#1747483586852610...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000046.png#1747483592493458...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000047.png#1747483585272453...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000048.png#1747483591578973...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000049.png#1747483592560939...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000050.png#1747483586063036...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000051.png#1747483586903230...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000052.png#1747483594383683...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000053.png#1747483595068337...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000054.png#1747483590061518...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000055.png#1747483587170152...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000056.png#1747483593552424...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000057.png#1747483585490791...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000058.png#1747483588899085...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000059.png#1747483586300205...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000060.png#1747483593853683...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000061.png#1747483585860332...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000062.png#1747483588899479...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000063.png#1747483594379621...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000064.png#1747483591413270...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000065.png#1747483595315108...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000066.png#1747483594358259...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000067.png#1747483593601987...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000068.png#1747483597532401...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000069.png#1747483596991364...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000070.png#1747483593371195...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000071.png#1747483591279967...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000072.png#1747483591404917...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000073.png#1747483586229229...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000074.png#1747483590612026...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000075.png#1747483589052699...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000076.png#1747483597610768...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000077.png#1747483596266446...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000078.png#1747483595652355...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000079.png#1747483592677974...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000080.png#1747483592354296...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000081.png#1747483590598483...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000082.png#1747483596069652...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000083.png#1747483588025461...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000084.png#1747483588409503...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000085.png#1747483592349676...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000086.png#1747483595297045...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000087.png#1747483598064047...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000088.png#1747483593709795...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000089.png#1747483591456117...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000090.png#1747483597053884...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000091.png#1747483590893763...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000092.png#1747483597456395...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000093.png#1747483592258710...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000094.png#1747483596845114...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000095.png#1747483588610093...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000096.png#1747483598010455...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000097.png#1747483587153931...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000098.png#1747483588247045...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000099.png#1747483586745480...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000100.png#1747483586421996...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000101.png#1747483593267284...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000102.png#1747483595130594...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000103.png#1747483587593288...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000104.png#1747483590929111...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000105.png#1747483589241236...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000106.png#1747483591752662...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000107.png#1747483589157159...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000108.png#1747483589833594...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000109.png#1747483588637751...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000110.png#1747483588173982...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000111.png#1747483596559042...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/images/00000112.png#1747483593902921...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/0/cameras.bin#1747483584466663...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/0/images.bin#1747483586243009...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/0/points3D.bin#1747483586599331...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/0/project.ini#1747483583843974...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/1/cameras.bin#1747483583865277...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/1/images.bin#1747483583987121...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/1/points3D.bin#1747483584555144...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse/1/project.ini#1747483585157585...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse_text/cameras.txt#1747483584326431...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse_text/images.txt#1747483585536381...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/sparse_text/points3D.txt#1747483585083397...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/transforms.json#1747483582870185...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/transforms_test.json#1747483584571381...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/transforms_train.json#1747483583582496...
# Removing gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom/transforms_val.json#1747483583737211...
# / [472/472 objects] 100% Done 24.56 objects/s ETA 00:00:00
# Operation completed over 472 objects.

# %%
# sending all room folder files in all shot & few shot folders to GCS bucket
from google.colab import auth
from pathlib import Path
import subprocess

auth.authenticate_user()

PROJECT_ID = 'cs231n-project-459006'
BUCKET = 'gs://cs231n-data-459006'

DST_ROOT = f'{BUCKET}/iphone_processed'
DST_ALL = f'{DST_ROOT}/allshot'
DST_FEW = f'{DST_ROOT}/fewshot'

OUT_ROOT = Path('/content/drive/My Drive/cs231n_nerf/datasets/iphone_processed')

for mode, subdir in [
    ('allshot_hashnerf_processed', 'allshot'),
    ('fewshot_hashnerf_processed', 'fewshot')
]:
  local = OUT_ROOT / mode
  dst = f'{DST_ROOT}/{subdir}'
  if not local.is_dir():
    print(f'Missing folder {local}')
    continue

  for room_dir in local.iterdir():
    if not room_dir.is_dir():
      print(f'Missing folder {room_dir.name}')
      continue

    print(f'Uploading {room_dir.name} to {dst}/{room_dir.name}')
    subprocess.run(['gsutil', '-m', 'cp', '-r', str(room_dir), f'{dst}/{room_dir.name}'], check=True)
# Out:
# Uploading norcliffe_common_room to gs://cs231n-data-459006/iphone_processed/allshot/norcliffe_common_room
# Uploading suites_bedroom to gs://cs231n-data-459006/iphone_processed/allshot/suites_bedroom
# Uploading norcliffe_common_room to gs://cs231n-data-459006/iphone_processed/fewshot/norcliffe_common_room
# Uploading suites_bedroom to gs://cs231n-data-459006/iphone_processed/fewshot/suites_bedroom

# %%
# !gcloud config set project cs231n-project-459006
# !gcloud config set compute/zone asia-northeast3-c

# !VM_NAME=nvidia-nerf-vm
# !REMOTE_FILE='~/norcliffe_baseline_hashXYZ_sphereVIEW_fine1024_log2T19_lr0.0005_decay500_RAdam_sparse1e-10_TV1e-06_spiral_005000_disp.mp4'

# !gcloud compute scp ${VM_NAME}:${REMOTE_FILE}  ./

# !open *_disp.mp4
# Out:
# Updated property [core/project].
# ERROR: (gcloud.config.set) You do not currently have an active account selected.
# Please run:
#
#   $ gcloud auth login
#
# to obtain new credentials.
#
# If you have already logged in with a different account, run:
#
#   $ gcloud config set account ACCOUNT
#
# to select an already authenticated account to use.
# WARNING: The private SSH key file for gcloud does not exist.
# WARNING: The public SSH key file for gcloud does not exist.
# WARNING: You do not have an SSH key for gcloud.
# WARNING: SSH keygen will be executed to generate a key.
# This tool needs to create the directory [/root/.ssh] before being able to
# generate SSH keys.
#
# Do you want to continue (Y/n)?
#
# Command killed by keyboard interrupt
#
# ^C
# xdg-open: file '*_disp.mp4' does not exist
